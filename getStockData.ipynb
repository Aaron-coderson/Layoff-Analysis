# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly
import matplotlib.pyplot as plt
import plotly.express as px
import os
import requests
from tqdm import tqdm
from dotenv import load_dotenv
import requests
from datetime import datetime, timedelta

# %%
dir = "projects/repo/Layoff-Analysis/"

# %%
df = pd.read_csv(dir + "data2/clean_with_ticker.csv")

# %%
df
# Out:
#             Company         Location HQ  # Laid Off        Date     %  \
# 0             Intel          Sacramento     22000.0  2025-04-23   20%
# 1          AppLovin         SF Bay Area        97.0  2025-04-16   NaN
# 2            Sonder         SF Bay Area         NaN  2025-04-14   NaN
# 3            Google         SF Bay Area         NaN  2025-04-11   NaN
# 4    Marin Software         SF Bay Area         NaN  2025-04-10  100%
# ..              ...                 ...         ...         ...   ...
# 893          Redfin             Seattle       236.0  2020-04-07    7%
# 894        Bitfarms     Quebec,Non-U.S.         NaN  2020-04-06   NaN
# 895        MindBody     San Luis Obispo       700.0  2020-04-02   35%
# 896           Maven             Seattle        31.0  2020-03-30    9%
# 897            Mogo  Vancouver,Non-U.S.        78.0  2020-03-27   30%
#
#         Industry                                             Source     Stage  \
# 0       Hardware  https://www.bloomberg.com/news/articles/2025-0...  Post-IPO
# 1      Marketing  https://www.pocketgamer.biz/applovin-lays-off-...  Post-IPO
# 2         Travel  https://skift.com/2025/04/14/sonder-announces-...  Post-IPO
# 3       Consumer  https://www.reuters.com/technology/google-lays...  Post-IPO
# 4      Marketing  https://searchengineland.com/marin-software-sh...  Post-IPO
# ..           ...                                                ...       ...
# 893  Real Estate  https://www.geekwire.com/2020/redfin-lays-off-...  Post-IPO
# 894       Crypto  https://coingeek.com/job-losses-loom-at-bitfar...  Post-IPO
# 895      Fitness  https://www.sanluisobispo.com/news/business/ar...  Post-IPO
# 896        Media  https://www.businesswire.com/news/home/2020033...  Post-IPO
# 897      Finance  https://betakit.com/mogo-lays-off-30-percent-o...  Post-IPO
#
#     $ Raised (mm)        Country Date Added Ticker
# 0             $12  United States  4/23/2025   INTC
# 1           $1600  United States  4/18/2025    APP
# 2            $839  United States  4/16/2025   SOND
# 3             $26  United States  4/16/2025   GOOG
# 4             $99  United States  4/16/2025   MRIN
# ..            ...            ...        ...    ...
# 893          $319  United States   4/7/2020   RDFN
# 894           $25         Canada   4/8/2020   BITF
# 895          $114  United States   4/2/2020    NaN
# 896           $77  United States   4/7/2020  96W.F
# 897          $201         Canada   4/3/2020   MOGO
#
# [898 rows x 12 columns]

# %%
df = df[df["Ticker"].notnull()]

# %%
df = df[df["Country"]=="United States"]

# %%
df = df.drop(["Source"], axis=1)

# %%
df = df.reset_index(drop=True)

# %%
load_dotenv()
alphaKey = os.getenv("ALPHAVANTAGE_API_KEY")
